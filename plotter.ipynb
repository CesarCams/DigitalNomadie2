# %%
from plot import *
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/martinmoureau/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## Lenght of Tweets

# %%
# Define file paths
data_paths = [
    'data/twitter-datasets/train_neg_full.txt',
    'data/twitter-datasets/train_pos_full.txt'
]
clean_paths = [
    'data/twitter-datasets/test_data.txt'
]

# Example 2: Plot a kernel density estimate (KDE) of character counts
tweet_length_plotter(data_paths, clean_paths, count_words=True, normalize=True, plot_type='kde')
# Out:
# /Users/martinmoureau/Documents/GitHub/DigitalNomadie2/plot.py:69: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(lengths, shade=True, label=label, color=color)
# /Users/martinmoureau/Documents/GitHub/DigitalNomadie2/plot.py:69: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(lengths, shade=True, label=label, color=color)
# /Users/martinmoureau/Documents/GitHub/DigitalNomadie2/plot.py:69: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(lengths, shade=True, label=label, color=color)

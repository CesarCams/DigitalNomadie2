# %%
from plot import *
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/martinmoureau/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## Lenght of Tweets

# %%
# Define file paths
data_paths = [
    'data_intern/twitter-datasets/train_neg_full.txt',
    'data_intern/twitter-datasets/train_pos_full.txt'
]
clean_paths = [
    'data_intern/twitter-datasets/test_data.txt'
]
vocab_path = "vocab_cut.txt"

# Example 2: Plot a kernel density estimate (KDE) of character counts
tweet_length_plotter(data_paths, clean_paths, vocab_path, count_words=True, normalize=True, plot_type='kde')
# Out:
# /Users/martinmoureau/Documents/GitHub/new_clone/DigitalNomadie2/plot.py:111: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(lengths, shade=True, label=label, color=color)
# /Users/martinmoureau/Documents/GitHub/new_clone/DigitalNomadie2/plot.py:111: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(lengths, shade=True, label=label, color=color)
# /Users/martinmoureau/Documents/GitHub/new_clone/DigitalNomadie2/plot.py:111: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(lengths, shade=True, label=label, color=color)

# %%
import numpy as np

data_path = "data_intern/twitter-datasets/"
test_path = f"{data_path}test_data.txt"
trainP_path = f"{data_path}train_pos_full.txt"
trainN_path = f"{data_path}train_neg_full.txt"

# Load and clean tweets
def load_and_clean_test_tweets(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        tweets = file.readlines()
    test_tweets = [re.sub(r"^\d+,\s*", "", tweet).strip() for tweet in tweets]
    return test_tweets

def load_tweets(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        tweets = file.readlines()
    return tweets

# Load datasets
test_tweets = load_and_clean_test_tweets(test_path)
trainP_tweets = load_tweets(trainP_path)
trainN_tweets = load_tweets(trainN_path)

# Combine labeled data
train_tweets = np.concatenate((trainP_tweets, trainN_tweets))
print(train_tweets.shape)
print(len(test_tweets))
# Out:
# (2500000,)
# 10000

# %%
import numpy as np

def count_unique_tweets(tweets):
    """
    Function to count the number of unique tweets in a numpy array.

    Parameters:
        tweets (np.array): A numpy array containing tweet texts.

    Returns:
        int: Number of unique tweets.
    """
    # Ensure the input is a numpy array
    tweets = np.array(tweets, dtype=str)
    
    # Use np.unique to find distinct tweets
    unique_tweets = np.unique(tweets)
    
    # Return the count of unique tweets
    return len(unique_tweets)


# Count unique tweets
num_unique_tweets = count_unique_tweets(train_tweets)
print(f"Number of unique tweets: {num_unique_tweets}")
# Out:
# Number of unique tweets: 2268591

# %%
data_paths = [
    'data_intern/twitter-datasets/train_neg_full.txt',
    'data_intern/twitter-datasets/train_pos_full.txt'
]
clean_paths = [
    'data_intern/twitter-datasets/test_data.txt'
]

print(count_tweets_above_word_threshold(data_paths, clean_paths, 40))
print(ratio_tweets_above_word_threshold(data_paths, clean_paths, 40))
# Out:
# 1038
# 0.0004135458167330677

# %%
# Mock file paths (replace these with actual paths)
data_paths = ["data_intern/twitter-datasets/train_neg_full.txt", "data_intern/twitter-datasets/train_pos_full.txt"]
clean_paths = ["data_intern/twitter-datasets/test_data.txt"]
vocab_path = "vocab_cut.txt"

# Call the function
top_words = top_100_words_from_datasets(data_paths, clean_paths, vocab_path, min_word_length=5)
    
# Print the top 100 words and their occurrences
for word, count in top_words:
    print(f"{word}: {count}")
# Out:
# <user>: 1611759
# <url>: 528932
# frame: 102828
# follow: 92474
# don't: 85085
# please: 81976
# thanks: 69097
# about: 64626
# really: 63625
# today: 60578
# can't: 59793
# going: 56904
# think: 55238
# there: 51399
# would: 46227
# paperback: 43841
# still: 41148
# thank: 40061
# never: 39693
# night: 39596
# happy: 39137
# right: 38996
# tomorrow: 38114
# that's: 37208
# people: 35411
# you're: 35339
# black: 34819
# gonna: 34156
# wanna: 33850
# picture: 33603
# complete: 32361
# school: 32159
# great: 31761
# should: 31283
# always: 31168
# could: 30598
# better: 29394
# sorry: 27771
# tonight: 27450
# poster: 26904
# though: 26881
# because: 26371
# tweet: 26088
# again: 25791
# first: 25429
# custom: 25187
# morning: 24641
# sleep: 24636
# twitter: 24404
# birthday: 24218
# friends: 23398
# edition: 22921
# where: 22901
# someone: 22858
# little: 22136
# phone: 22090
# didn't: 21951
# being: 21628
# world: 21609
# watch: 21576
# getting: 21297
# after: 20834
# everyone: 20371
# ...
